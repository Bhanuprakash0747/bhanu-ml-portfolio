# %% [markdown]
# # XOR Problem Implementation

# %%
import numpy as np
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

y = np.array([[0], [1], [1], [0]])
print(xi.shape, W.shape, b.shape, error.shape)
# Out:
# (1, 2) (2, 1) (1, 1) (1, 1)

# %%
W = np.random.randn(2, 1)
b = np.random.randn(1, 1)

def step(z):
    return (z >= 0).astype(int)

lr = 0.1
for epoch in range(1000):
    for i in range(len(X)):
        xi = X[i].reshape(1, -1)
        yi = y[i]

        z = np.dot(xi, W) + b
        y_pred = step(z)

        error = yi - y_pred

        W += lr * xi.T * error
        b += lr * error
print("Predictions:")
print(step(np.dot(X, W) + b))
# Out:
# Predictions:
# [[1]
#  [1]
#  [0]
#  [0]]

# %% [markdown]
# ## Neural Network (Solution)?? Upcoming Days
